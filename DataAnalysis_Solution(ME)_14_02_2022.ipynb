# %% [markdown]
# <a href="https://colab.research.google.com/github/merdogan97/DVwPy/blob/main/DataAnalysis_Solution(ME)_14_02_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## G9 Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("udemy_courses.csv")
df = data.copy()
# ........ (6 satır olacak şekilde dataframe içerisinden random verileri getirecek olan kodu yazınız )

# %%
df.info
# Out:
# <bound method DataFrame.info of       course_id  ...           subject
# 0       1070968  ...  Business Finance
# 1       1113822  ...  Business Finance
# 2       1006314  ...  Business Finance
# 3       1210588  ...  Business Finance
# 4       1011058  ...  Business Finance
# ...         ...  ...               ...
# 3673     775618  ...   Web Development
# 3674    1088178  ...   Web Development
# 3675     635248  ...   Web Development
# 3676     905096  ...   Web Development
# 3677     297602  ...   Web Development
#
# [3678 rows x 12 columns]>

# %%
df.shape
# Out:
# (3678, 12)

# %%
df.head()
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
# 1    1113822  ...  Business Finance
# 2    1006314  ...  Business Finance
# 3    1210588  ...  Business Finance
# 4    1011058  ...  Business Finance
#
# [5 rows x 12 columns]

# %%
df.sample(10)
# Out:
#       course_id  ...              subject
# 471      403628  ...     Business Finance
# 2436     568322  ...  Musical Instruments
# 2888    1156648  ...      Web Development
# 2561      28295  ...      Web Development
# 2663     582392  ...      Web Development
# 2061     635570  ...  Musical Instruments
# 2139    1243162  ...  Musical Instruments
# 829      130298  ...     Business Finance
# 983     1110256  ...     Business Finance
# 3363     596192  ...      Web Development
#
# [10 rows x 12 columns]

# %%
df.describe()
# Out:
#           course_id        price  ...  num_lectures  content_duration
# count  3.678000e+03  3678.000000  ...   3678.000000       3678.000000
# mean   6.759720e+05    66.049483  ...     40.108755          4.094517
# std    3.432732e+05    61.005755  ...     50.383346          6.053840
# min    8.324000e+03     0.000000  ...      0.000000          0.000000
# 25%    4.076925e+05    20.000000  ...     15.000000          1.000000
# 50%    6.879170e+05    45.000000  ...     25.000000          2.000000
# 75%    9.613555e+05    95.000000  ...     45.750000          4.500000
# max    1.282064e+06   200.000000  ...    779.000000         78.500000
#
# [8 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.isnull()
# Out:
#       course_id  course_title  ...  published_timestamp  subject
# 0         False         False  ...                False    False
# 1         False         False  ...                False    False
# 2         False         False  ...                False    False
# 3         False         False  ...                False    False
# 4         False         False  ...                False    False
# ...         ...           ...  ...                  ...      ...
# 3673      False         False  ...                False    False
# 3674      False         False  ...                False    False
# 3675      False         False  ...                False    False
# 3676      False         False  ...                False    False
# 3677      False         False  ...                False    False
#
# [3678 rows x 12 columns]

# %%
df.isnull().sum()                           # Toplam Null sayısı
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df
# Out:
#       course_id  ...           subject
# 0       1070968  ...  Business Finance
# 1       1113822  ...  Business Finance
# 2       1006314  ...  Business Finance
# 3       1210588  ...  Business Finance
# 4       1011058  ...  Business Finance
# ...         ...  ...               ...
# 3673     775618  ...   Web Development
# 3674    1088178  ...   Web Development
# 3675     635248  ...   Web Development
# 3676     905096  ...   Web Development
# 3677     297602  ...   Web Development
#
# [3678 rows x 12 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
df.duplicated().sum()                                                    # duplicated değerlerin silinmesi
# Out:
# 0

# %% [markdown]
# - Udemy'de çalışan bir veri analistisiniz. Elinizde bulunan verileri okunayarak anlamlı sonuçlar çıkaracaksınız.Aşağıda yazan başlıklar sadece örnek amaçlıdır. Veri analisti olarak doğru soruları sorup, şirket için faydalı bilgilere ulaşmanız gerekiyor.
#
# Örn:
#
# Kursların ücretli olmasıyla talebi arasındaki ilişkiler..
#
# Kurs çeşitleri ile talep arasındaki ilşki..
#
# En çok talep edilen kurslar ve muhtemel talep sebebi..
#
# Kursların dağılımları ile ilgili bilgiler..
#
# Yıllara göre bu kursların konu konu dağılımlarına göre çıkarımlar..
#
# Kurs subjectlerinin yıllara göre değişimi..

# %% [markdown]
# - Not : Varsa gerekli görülmeyen sutunları düşebilir veya sutunlardan yeni sutunlar oluşturabilirsiniz.

# %%
df.sample(5)
# Out:
#       course_id  ...              subject
# 619      619792  ...     Business Finance
# 3631     935014  ...      Web Development
# 241      480752  ...     Business Finance
# 1134    1041926  ...     Business Finance
# 2144     445118  ...  Musical Instruments
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   object
#  11  subject              3672 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 347.8+ KB

# %%
df.course_title.nunique()
# Out:
# 3663

# %%
df.course_title.unique()
# Out:
# array(['Ultimate Investment Banking Course',
#        'Complete GST Course & Certification - Grow Your CA Practice',
#        'Financial Modeling for Business Analysts and Consultants', ...,
#        'Learn and Build using Polymer',
#        'CSS Animations: Create Amazing Effects on Your Website',
#        "Using MODX CMS to Build Websites: A Beginner's Guide"],
#       dtype=object)

# %%
df.is_paid.unique()
# Out:
# array([ True, False])

# %%
x = df.price.value_counts().values

# %%
y = df.num_subscribers.value_counts().index

# %% [markdown]
# # **#kurs çeşitleri ve talep ilişkisi:**

# %%
df.head(1)
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
#
# [1 rows x 12 columns]

# %%
df.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# # **Kurs subjectlerinin yıllara göre değişimi..**

# %%
type(df["published_timestamp"][10])
# Out:
# str

# %%
df.published_timestamp = pd.to_datetime(df['published_timestamp'])

# %%
df.head(1)
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
#
# [1 rows x 12 columns]

# %%
df["timestamp"]=df.published_timestamp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   object
#  12  timestamp            3672 non-null   datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](2), float64(1), int64(5), object(4)
# memory usage: 505.6+ KB

# %%
df.timestamp
# Out:
# 0      2017-01-18 20:58:58+00:00
# 1      2017-03-09 16:34:20+00:00
# 2      2016-12-19 19:26:30+00:00
# 3      2017-05-30 20:07:24+00:00
# 4      2016-12-13 14:57:18+00:00
#                   ...
# 3673   2016-06-14 17:36:46+00:00
# 3674   2017-03-10 22:24:30+00:00
# 3675   2015-12-30 16:41:42+00:00
# 3676   2016-08-11 19:06:15+00:00
# 3677   2014-09-28 19:51:11+00:00
# Name: timestamp, Length: 3672, dtype: datetime64[ns, UTC]

# %%
df.set_index("timestamp", inplace=True)

# %%
df.head(2)
# Out:
#                            course_id  ... month
# timestamp                             ...
# 2017-01-18 20:58:58+00:00    1070968  ...     1
# 2017-03-09 16:34:20+00:00    1113822  ...     3
#
# [2 rows x 15 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-18 20:58:58+00:00', '2017-03-09 16:34:20+00:00',
#                '2016-12-19 19:26:30+00:00', '2017-05-30 20:07:24+00:00',
#                '2016-12-13 14:57:18+00:00', '2014-05-02 15:13:30+00:00',
#                '2016-02-21 18:23:12+00:00', '2015-01-30 22:13:03+00:00',
#                '2015-05-28 00:14:03+00:00', '2017-04-18 18:13:32+00:00',
#                ...
#                '2014-08-10 20:19:10+00:00', '2015-11-29 22:02:02+00:00',
#                '2014-12-19 21:38:54+00:00', '2015-11-19 17:22:47+00:00',
#                '2016-10-10 22:00:32+00:00', '2016-06-14 17:36:46+00:00',
#                '2017-03-10 22:24:30+00:00', '2015-12-30 16:41:42+00:00',
#                '2016-08-11 19:06:15+00:00', '2014-09-28 19:51:11+00:00'],
#               dtype='datetime64[ns, UTC]', name='timestamp', length=3672, freq=None)

# %%
df.index.year
# Out:
# Int64Index([2017, 2017, 2016, 2017, 2016, 2014, 2016, 2015, 2015, 2017,
#             ...
#             2014, 2015, 2014, 2015, 2016, 2016, 2017, 2015, 2016, 2014],
#            dtype='int64', name='timestamp', length=3672)

# %%
f = lambda x: x.strftime("%Y-%m")

# %%
f(df.index)
# Out:
# Index(['2017-01', '2017-03', '2016-12', '2017-05', '2016-12', '2014-05',
#        '2016-02', '2015-01', '2015-05', '2017-04',
#        ...
#        '2014-08', '2015-11', '2014-12', '2015-11', '2016-10', '2016-06',
#        '2017-03', '2015-12', '2016-08', '2014-09'],
#       dtype='object', name='timestamp', length=3672)

# %%
df["year_month"] = f(df.index)
df["year"]=df.index.year
df["month"]=df.index.month

# %%
df.sample(5)
# Out:
#                            course_id  ... month
# timestamp                             ...
# 2017-03-27 16:45:29+00:00    1132162  ...     3
# 2016-04-13 06:57:11+00:00     744034  ...     4
# 2015-09-21 17:12:21+00:00     601092  ...     9
# 2016-01-08 17:16:48+00:00     713098  ...     1
# 2016-10-13 20:38:03+00:00     983534  ...    10
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year_month',
#        'year', 'month'],
#       dtype='object')

# %% [markdown]
# # **Yıllara göre ücretler**

# %%
plt.figure(figsize=(20, 10)) 
sns.lineplot(data=df, x=df.index, y = "price");

# %%
plt.figure(figsize=(20, 6)) 
sns.pointplot(data=df, x = "year", y="price", ci=None);

# %%
plt.figure(figsize=(20, 6)) 
sns.pointplot(data=df, x = "year_month", y="price", ci=None);

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "year", y="price",ci= 60);

# %% [markdown]
# # **VISUALIZING THE CORRELATION WITH A HEATMAP**

# %%
df.corr()[["price"]]
# Out:
#                      price
# course_id         0.143062
# is_paid           0.328910
# price             1.000000
# num_subscribers   0.050436
# num_reviews       0.113568
# num_lectures      0.329944
# content_duration  0.293200
# year              0.133654
# month             0.038506

# %%
corr_price = df.corr()[["price"]].sort_values(by="price", ascending=False)
corr_price
# Out:
#                      price
# price             1.000000
# num_lectures      0.329944
# is_paid           0.328910
# content_duration  0.293200
# course_id         0.143062
# year              0.133654
# num_reviews       0.113568
# num_subscribers   0.050436
# month             0.038506

# %%
plt.figure(figsize=(3, 6)) 
sns.heatmap(corr_price, annot= True, cmap="BrBG", vmin= -1, vmax= 1)

# %%
plt.figure(figsize=(20,12)) 
sns.heatmap(df.corr(), annot= True, cmap="coolwarm");

# %%
plt.figure(figsize=(10, 6)) 
df.corr()["price"].sort_values().plot.bar();

# %% [markdown]
# # ***Yıllara göre bu kursların konu konu dağılımlarına göre çıkarımlar.. ***

# %%
df.year.value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: year, dtype: int64

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "year", y="price", hue= "subject")

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "year", y="price", hue= "subject")

# %%
plt.figure(figsize=(20, 6)) 
sns.catplot(data=df, x = "year", y="price", hue= "subject")

# %% [markdown]
# # **Kursların Dağılımı ile Bilgiler:**

# %%
plt.figure(figsize=(7,4))
sns.countplot(x ="subject", data=df);

# %%
sns.catplot(x="subject", data=df, kind="count");

# %%
sns.catplot(x="subject", data=df, kind="count", col="level");

# %% [markdown]
# # **En çok talep edilen kurslar ve muhtemel talep sebebi..**
# # **Kurs çeşitleri ile talep arasındaki ilşki..**

# %%
df.head(2)
# Out:
#                            course_id  ... month
# timestamp                             ...
# 2017-01-18 20:58:58+00:00    1070968  ...     1
# 2017-03-09 16:34:20+00:00    1113822  ...     3
#
# [2 rows x 15 columns]

# %%
df_sum = df.groupby("subject").num_subscribers.sum()
df_sum
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7937287
# Name: num_subscribers, dtype: int64

# %%
df_sum.index
# Out:
# Index(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'],
#       dtype='object', name='subject')

# %%
df_sum.values
# Out:
# array([1868711, 1063148,  846689, 7937287])

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "subject"  , y="num_subscribers", ci=None);

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "subject"  , y="num_subscribers");

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "subject", y="num_subscribers",ci= 90);

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "subject", y="num_subscribers", hue= "is_paid")

# %%
plt.figure(figsize=(60, 10)) 
sns.catplot(data=df, x = "subject", y="num_subscribers", hue= "is_paid")

# %% [markdown]
# # **Kursların ücretli olmasıyla talep arasındaki ilişkiler..**

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="num_subscribers", ci=None)

# %%
plt.figure(figsize=(20, 6)) 
sns.pointplot(data=df, x = "price", y="num_subscribers", ci=None)

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="num_subscribers")

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="num_subscribers", hue="level")

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="num_subscribers", hue="level", ci=None)

# %%
plt.figure(figsize=(90, 6)) 
sns.barplot(data=df, x = "price", y="num_subscribers")

# %% [markdown]
# # **Kurs level(Seviye) ile talep ilişkileri..**

# %%
fig, ax = plt.subplots()

# weather_code
sns.countplot(x='level',data=df);

# %% [markdown]
# # **Kursa katılanların ödeme yapma ilişkisi**

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="num_subscribers", hue="is_paid")

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "price", y="num_subscribers", hue="is_paid")

# %% [markdown]
# # **Ücret ve ödenme ilişkisi**

# %%
fig, ax= plt.subplots()    
sns.countplot(x=df['is_paid']);
for p in ax.patches:
  ax.annotate(p.get_height(),(p.get_x()+0.3,p.get_height()+30 ))

# %%
plt.figure(figsize=(20, 6)) 
sns.lineplot(data=df, x = "price", y="is_paid")

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "price", y="is_paid")

# %%
plt.figure(figsize=(20, 6)) 
sns.barplot(data=df, x = "subject", y="price", hue="is_paid")

# %% [markdown]
# # **Levellara göre dağılım ilişkisi**

# %%
fig, ax= plt.subplots()    
sns.countplot(x=df['level']);
for p in ax.patches:
  ax.annotate(p.get_height(),(p.get_x()+0.3,p.get_height()+30 ))
